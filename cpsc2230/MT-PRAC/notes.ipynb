# %%
int main( int argc, char **argv) { //note double star -> an array of arrays
    printf("number of arguments: %d\n", argc);
    for (size_t i = 0; i < argc; i++) { 
        printf("argument %d: %s", i, argv[i]);
    }
}
